# %% [markdown]
# <a href="https://colab.research.google.com/github/dooooing/2023-ESAA-/blob/main/0324_%EC%A0%9C%EC%B6%9C_%EA%B3%BC%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **두잇 데이터 분석을 위한 판다스 입문(81-119p)**

# %% [markdown]
# **04-1. 데이터 시각화가 필요한 이유**
#
#
# 앤스콤 4분할 그래프 살펴보기
# 앤크콤 4분할 그래프(Anscombe's quarter): 데이터 시각화를 보여주는 전형적인 사례. 데이터를 시각화하지 않고 수치만 확인할 때 발생할 수 있는 함정을 보여주기 위해 만든 그래프.
#
# \* 앤스콤이 지적한 함정과 데이터 시각화의 필요성
# 4개의 데이터 그룹은 각각 평균, 분산과 같은 수칫값이나 상관관계, 회귀선이 같다는 특징이 있다.그래서 이런 결과만 보고 '데이터 그룹 I, II, III, IV의 데이터는 모두 같을 것이다'라고 착각할 수 있다는 것이 앤스콤이 지적한 '함정'이다.
# 각 데이터 그룹을 시각화하면 데이터 그룹이 서로 다른 데이터 패턴을 가지고 있다는 점을 금방 알 수 있다.

# %% [markdown]
# 1. 앤스콤 데이터 집합 불러오기
# 앤스콤 데이터 집합은 seaborn 라이브러리에 포함되어 있음.
# seaborn 라이브러리의 load_dataset 메서드에 문자열 anscombe을 전달해 앤스콤 데이터 집합을 불러온다.

# %%
import pandas as pd
import numpy as np

import seaborn as sns

anscombe = sns.load_dataset("anscombe")
print(anscombe)
print(type(anscombe))
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %% [markdown]
# 2. matplotlib 라이브러리로 그래프 그리기
# 데이터 집합이 준비되었으면 그래프로 시각화
# 그래프를 그리기 위해 matplotlib 라이브러리 사용

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# 3. anscombe 데이터프레임의 dataset 열에서 데이터 값이 I인 것만 추출. 즉, 첫 번째 데이터 그룹 추출.

# %%
dataset_1 = anscombe[anscombe['dataset'] == 'I']

# %% [markdown]
# 4. 선 그래프는 plot 메서드로 그릴 수 있음. plot 메서드에 x, y축 데이터를 전달하면 선 그래프가 나타남.
#
# dataset_1의 x, y 열 전달

# %%
plt.plot(dataset_1['x'],dataset_1['y'])

# %% [markdown]
# 5. plot 메서드는 기본적으로 선으로 그래프를 그림. 점으로 그래프를 그리려면 o를 세 번째 인자로 전달.

# %%
plt.plot(dataset_1['x'], dataset_1['y'], 'o')

# %% [markdown]
# **앤스콤 데이터 집합 모두 사용해 그래프 만들기**
# 4개의 데이터 그룹으로 구성. 각 데이터 그룹의 차이를 파악하려면 그래프로 시각화해야 함.

# %% [markdown]
# matplotlib 라이브러리로 그래프 그리기
#
#
# 1.   전체 그래프가 위치할 기본 틀 만들기
# 2.   그래프를 그려 넣을 그래프 격자 만들기
# 3.   격자에 그래프 하나씩 추가. (왼쪽에서 오른쪽 방향)
# 4.   만약 격자의 첫 번째 행에 꽉 차면 두 번째 행에 그래프를 그려 넣음.

# %% [markdown]
# <한 번에 4개의 그래프 그리기>
# 1. 앤스콤 데이터프레임의 dataset 열의 값이 I, II, III, IV인 것을 불린 추출하여 dataset_1,2,3,4에 저장.

# %%
#dataset_1은 앞에서 이미 추출했음.
dataset_2 = anscombe[anscombe['dataset'] == 'II']
dataset_3 = anscombe[anscombe['dataset'] == 'III']
dataset_4 = anscombe[anscombe['dataset'] == 'IV']

# %% [markdown]
# 2. 그래프 격자가 위치할 기본 틀 만들기

# %%
fig = plt.figure()

# %% [markdown]
# 3. add_plot 메서드로 그래프 격자 그리기 (기본 틀(fig)에 격자를 추가하는 느낌으로 사용하면 됨)
# add_subplot(그래프 기본 틀의 행 크기, 그래프 기본 틀의 열 크기)

# %%
axes1 = fig.add_subplot(2,2,1)
axes2 = fig.add_subplot(2,2,2) 
axes3 = fig.add_subplot(2,2,3) 
axes4 = fig.add_subplot(2,2,4)

# %% [markdown]
# 4. plot 메서드에 데이터 전달해 그래프 그리기 (그래프를 확인하려면 fig를 반드시 입력해야 함)

# %%
axes1.plot(dataset_1['x'], dataset_1['y'], 'o')
axes2.plot(dataset_2['x'], dataset_2['y'], 'o')
axes3.plot(dataset_3['x'], dataset_3['y'], 'o')
axes4.plot(dataset_4['x'], dataset_4['y'], 'o')

fig

# %% [markdown]
# 5. 그래프 격자에 제목 추가(set_title)

# %%
axes1.set_title("dataset_1")
axes2.set_title("dataset_2")
axes3.set_title("dataset_3")
axes4.set_title("dataset_4")

fig

# %% [markdown]
# 6. 기본 틀(fig)에 제목 추가 (suptitle)

# %%
fig.suptitle("Anscombe Data")

fig

# %% [markdown]
# 7. 그래프 레이아웃 조절 (tight_layout)

# %%
fig.tight_layout()

fig

# %% [markdown]
# **04-2. matplotlib 라이브러리 자유자재로 사용하기**
#
# **기초 그래프 그리기**

# %% [markdown]
# 1. tips 데이터 집합을 불러와 변수 tips에 저장.
# tips 데이터프레임은 지불 금액, 팁, 성별, 흡연 유무, 요일, 시간, 전체 인원 정보를 담고 있음.

# %%
tips = sns.load_dataset("tips")
print(tips.head())
print(type(tips))
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# 2. 히스토그램은 데이터그레임의 열 데이터 분포와 빈도를 살펴보는 용도로 자주 사용하는 그래프.
# \* 이때 데이터 프레임의 total_bill, tip 등의 열을 변수라고 부르기도 함.
# \* 일변량 그래프: 변수를 하나만 사용해서 그린 그래프

# %% [markdown]
# 3. 기본 틀(fig) 마련, 그래프 격자(axes1) 구성

# %%
fig = plt.figure()
axes1 = fig.add_subplot(1,1,1)

# %% [markdown]
# 4. hist 메서드에 total_bill 열을 전달하면 히스토그램이 만들어짐. x축의 간격은 bins 인자값으로 조정. (나머지는 그래프/x축/y축 제목 추가하는 코드임)

# %%
axes1.hist(tips['total_bill'], bins=10)
axes1.set_title('Histogram of Total Bill')
axes1.set_xlabel('Frequency')
axes1.set_ylabel('Total Bill')

fig

# %% [markdown]
# 5. 산점도 그래프 그리기
# 산점도 그래프 - 변수 2개를 사용해서 만드는 그래프. (이변량 그래프)

# %% [markdown]
# 6. 기본 틀과 그래프 격자를 만들고 scatter 메서드에 total_bill, tips 열을 전달하면 산점도 그래프가 나타남.

# %%
scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1,1,1)
axes1.scatter(tips['total_bill'], tips['tip'])
axes1.set_title('Scatterplot of Total Bill vs Tip')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %% [markdown]
# 7. 박스 그래프 그리기
# 박스 그래프: 이산형 변수와 연속형 변수를 함께 사용하는 그래프
# 이산형 변수- 명확하게 구분되는 값 (ex. Female/Male), 연속형 변수- 명확하게 셀 수 없는 범위의 값 (ex. Tip)

# %% [markdown]
# 8. boxplot 메서드를 사용해 박스 그래프 그리기

# %%
boxplot = plt.figure()
axes1 = boxplot.add_subplot(1,1,1)

axes1.boxplot([tips[tips['sex'] == 'Female']['tip'],
              tips[tips['sex'] == 'Male']['tip']],
              labels=['Female', 'Male'])

axes1.set_xlabel('Sex')
axes1.set_ylabel('Tip')
axes1.set_title('Boxplot of Tips by Sex')
# Out:
# Text(0.5, 1.0, 'Boxplot of Tips by Sex')

# %% [markdown]
# **다변량 그래프 그리기**
# 다변량 그래프- 3개 이상의 변수를 사용한 그래프

# %% [markdown]
# **다변량 데이터로 다변량 그래프 그리기 - 산점도 그래프**

# %% [markdown]
# 1.앞에서 실습한 산점도 그래프(scatter_plot)에 성별을 새 변수로 추가. 성별은 색상으로 구분하면 적당.
# but, 문자열은 산점도 그래프의 색상을 지정하는 값으로 사용할 수 없으므로 0,1과 같은 정수를 사용해야 함.
# -> 문자열을 정수로 치환하는 함수 만들기

# %%
def recode_sex(sex):
  if sex=='Female':
    return 0
  else:
    return 1

# %% [markdown]
# 2. recode_sex가 반환한 값(0 or 1)을 데이터프레임에 추가
# sex_color 열을 새로 생성하여 추가. sex열에 recode_sex 함수를 브로드캐스팅하기 위하여 apply 메서드를 사용함.

# %%
tips['sex_color'] = tips['sex'].apply(recode_sex)

# %% [markdown]
# 3. 테이블당 인원 수(size) 산점도 그래프에 추가. (점의 크기로 표현하면 적당)
# scatter 메서드에 s, c 인자값으로 테이블당 인원 수와 성별의 치환값을 전달.

# %%
# s = size(점의 크기), c = color(점의 색상)
# alpha 인자값을 0.5로 지정하여 점의 투명도를 보기 좋게 조절함.
scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1,1,1)
axes1.scatter(
    x=tips['total_bill'],
    y=tips['tip'],
    s=tips['size']*10,
    c=tips['sex_color'],
    alpha=0.5)
axes1.set_title('Total Bill vs Tip Colored by Sex and Sized by Size')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %% [markdown]
# **04-3. seaborn 라이브러리 자유자재로 사용하기**
# seaborn 라이브러리를 활용하면 matplotlib보다 좀 더 화려한 그래프를 그릴 수 있다. (seaborn 라이브러리는 matplotlib 라이브러리를 기반으로 만든 라이브러리)

# %% [markdown]
# **단변량 그래프 그리기 - 히스토그램**

# %% [markdown]
# 1. seaborn 라이브러리를 sns라는 이름으로 줄여 사용. tips 데이터 집합 불러오기.

# %%
import seaborn as sns

tips = sns.load_dataset("tips")

# %% [markdown]
# 2. subplots, distplot 메서드를 사용해 seaborn 라이브러리로 히스토그램 그리기.
# subplots 메서드로 기본 틀을 만들고 -> distplot 메서드에 total_bill 열 데이터 전달

# %%
ax = plt.subplots()
ax = sns.distplot(tips['total_bill'])
ax.set_title('Total Bill Histogram with Density Plot')
# Out:
# <ipython-input-113-071bdf8959b6>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tips['total_bill'])
# Text(0.5, 1.0, 'Total Bill Histogram with Density Plot')

# %% [markdown]
# 3. displot 메서드를 사용하면 히스토그램과 밀집도 그래프를 같이 그린다. 밀집도 그래프를 제거하고 싶다면 kde 인자값을 False로 설정.
# (밀집도 그래프: 데이터를 정규화시켜 넓이가 1이 되도록 그린 그래프)

# %%
ax = plt.subplots()
ax = sns.distplot(tips['total_bill'], kde=False)
ax.set_title('Total Bill Histogram')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Frequency')
# Out:
# <ipython-input-114-29ef41561e71>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tips['total_bill'], kde=False)
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# 4. 밀집도 그래프만 나타내려면 hist 인자를 False로 지정

# %%
ax = plt.subplots()
ax = sns.distplot(tips['total_bill'], hist=False)
ax.set_title('Total Bill Density')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Unit Probability')
# Out:
# <ipython-input-115-a21e362b801d>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tips['total_bill'], hist=False)
# Text(0, 0.5, 'Unit Probability')

# %% [markdown]
# 5. 여러 데이터 한 번에 출력 - 실무 환경에서 데이터 시각화를 더 효율적으로 하기 위해
# 다음은 히스토그램과 밀집도를 그리는 distpot 메서드에 rug 인자를 추가하여 양탄자(rug) 그래프까지 그린 것.
# (양탄자 그래프: 그래프의 축에 동일한 길이의 직선을 붙여 데이터의 밀집 정도를 표현한 그래프)

# %%
ax = plt.subplots()
ax = sns.distplot(tips['total_bill'], rug=True)
ax.set_title('Total Bill Histogram with Density and Rug Plot')
ax.set_xlabel('Total Bill')
# Out:
# <ipython-input-116-177ef4c49b0e>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tips['total_bill'], rug=True)
# Text(0.5, 0, 'Total Bill')

# %% [markdown]
# 6. count 그래프: 이산값을 나타낸 그래프
#
# countplot 메서드에 tips 데이터프레임의 day 열 데이터를 넣어 count 그래프를 그려봄.

# %%
ax = plt.subplots()
ax = sns.countplot(x='day', data=tips)
ax.set_title('Day of the Week')
ax.set_xlabel('Frequency')
# Out:
# Text(0.5, 0, 'Frequency')

# %% [markdown]
# **다양한 종류의 이변량 그래프 그리기**

# %% [markdown]
# 1. seaborn 라이브러리로 산점도 그래프 그리기
# - seaborn 라이브러리는 matplotlib 라이브러리보다 다양한 방법으로 산점도 그래프를 그릴 수 있다.
# - seaborn 라이브러리의 regplot 메서드 이용
# - regplot 메서드 이용 -> 산점도 그래프, 회귀선 함께 그려짐 -> 회귀선을 제거하려면 fit-reg = False로 지정

# %%
ax = plt.subplots( )
ax = sns.regplot(x='total_bill', y='tip', data=tips) 
ax.set_title('Scatterplot of Total Bill and Tip') 
ax.set_xlabel('Total Bill') 
ax.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
ax = plt.subplots( )
ax = sns.regplot(x='total_bill', y='tip', data=tips, fit_reg=False) 
ax.set_title('Scatterplot of Total Bill and Tip') 
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %% [markdown]
# 2. jointplot: 산점도 그래프&히스토그램 한 번에 그려주는 메서드
# x,y 인자- 원하는 열 이름, data 인자값- 데이터프레임 지정

# %%
joint = sns.jointplot(x='total_bill', y='tip', data=tips) 
joint.set_axis_labels(xlabel='Total Bill', ylabel='Tip') 
joint.fig.suptitle('Joint Plot of Total Bill and Tip', fontsize=10, y=1.03)
# Out:
# Text(0.5, 1.03, 'Joint Plot of Total Bill and Tip')

# %% [markdown]
# 3. 산점도 그래프- 점이 겹쳐 보일 경우 구분하기 어렵다는 단점
# -> 육각 그래프(hexbin): 2차원 표면에 육각형으로 데이터를 쌓아 표현하는 그래프. 특정 데이터의개수가 많아지면 점점 진한 색으로 표현됨.
# kind = hex로 지정
# -> 육각 그래프 사용하면 데이터를 구분하기 쉽게 그린다.

# %%
hexbin = sns.jointplot(x="total_bill", y="tip", data=tips, kind="hex")
hexbin.set_axis_labels(xlabel='Total Bill', ylabel='Tip')
hexbin.fig.suptitle('Hexbin Joint Plot of Total Bill and Tip', fontsize=10, y=1.03)
# Out:
# Text(0.5, 1.03, 'Hexbin Joint Plot of Total Bill and Tip')

# %% [markdown]
# 4. 이차원 밀집도 그리기
# kdeplot 메서드로 만듦. shade = True로 지정하면 그래프에 음영 효과를 줄 수 있음.

# %%
ax=plt.subplots()
ax=sns.kdeplot(x=tips['total_bill'], y=tips['tip'], shade=True)
ax.set_title('Kernel Density Plot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# <ipython-input-122-9cd6de9c5d50>:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax=sns.kdeplot(x=tips['total_bill'], y=tips['tip'], shade=True)
# Text(0, 0.5, 'Tip')

# %% [markdown]
# 5. 바 그래프 그리기
# 바 그래프:지정한 변수의 평균을 계산하여 그린다.

# %%
ax = plt.subplots( )
ax = sns.barplot(x='time', y='total_bill', data=tips) 
ax.set_title('Bar plot of average total bill for time of day') 
ax.set_xlabel('Time of day') 
ax.set_ylabel('Average total bill')
# Out:
# Text(0, 0.5, 'Average total bill')

# %% [markdown]
# 6. 박스 그래프 그리기
# 최솟값, 1분위수, 중간값, 3분위수, 최댓값, 이상치 등 다양한 통계량을 한 번에 표현하는 그래프.

# %%
ax = plt.subplots( )
ax = sns.boxplot(x='time', y='total_bill', data=tips) 
ax.set_title('Boxplot of total bill by time of day') 
ax.set_xlabel('Time of day') 
ax.set_ylabel('Total Bill')
# Out:
# Text(0, 0.5, 'Total Bill')

# %% [markdown]
# 7. 박스그래프는 다양한 통꼐 수치를 확인하기 위해 자주 사용하는 그래프 but, 데이터 분산이 모호하게 표현됨.
# -> 바이올린 그래프: 박스 그래프에 커널 밀도를 추정한 그래프 사용 (violinplot 메서드 사용)

# %%
ax = plt.subplots( )
ax = sns.violinplot(x='time', y='total_bill', data=tips) 
ax.set_title('Violin plot of total bill by time of day') 
ax.set_xlabel('Time of day') 
ax.set_ylabel('Total Bill')
# Out:
# Text(0, 0.5, 'Total Bill')

# %% [markdown]
# 8. 관계 그래프 그리기
# 지금까지 설명한 그래프를 종합한 그래프. pairplot 메서드에 데이터프레임 넣기.

# %%
fig = sns.pairplot(tips)

# %% [markdown]
# 9. 관계 그래프를 중복된 정보가 표현된다는 단점이 있다. 대각선을 기준으로 절반씩 같음.
# -> 중복된 그래프가 그려지는 위치를 직접 지정하여 원하는 그래프로 교체.
# -> map_upper, map_lower, map_diag

# %%
pair_grid = sns.PairGrid(tips) 
pair_grid = pair_grid.map_upper(sns.regplot)  # 산점도 그래프
pair_grid = pair_grid.map_lower(sns.kdeplot)  # 이차원 밀집도
pair_grid = pair_grid.map_diag(sns.distplot, rug=True) # 히스토그램, 밀집도 
plt.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/axisgrid.py:1544: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(x=data_k, label=label_k, color=color, **plot_kwargs)
# /usr/local/lib/python3.9/dist-packages/seaborn/axisgrid.py:1544: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# **다변량 그래프 그리기**
# 1. seaborn 라이브러리로 바이올린 그래프 그리기 - 색상 추가
# hue = (색상에 사용할 열 이름)

# %%
ax=plt.subplots()
ax=sns.violinplot(x='time', y='total_bill', hue='sex', data=tips, split=True)

# %% [markdown]
# 2. 산점도, 관계 그래프 그리기 - 색상 추가

# %%
scatter = sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', fit_reg=False)

# %%
fig = sns.pairplot(tips, hue='sex')

# %% [markdown]
# 3. 산점도 그래프의 크기와 모양 조절하기
# 점 크기 조절 - scatter_kws에 딕셔너리 형태로 인자값 전달

# %%
# scatter = sns.lmplot(x='total_bill', y='tip', data=tips, fit_reg=False, hue='sex', 
#                     scatter_kws={'s': tips['size']*10}) 

# 위의 예제는 오류가 떠서 다른 방식 사용
scatter = sns.relplot(data = tips, x = 'total_bill', y = 'tip', 
                      hue = 'sex', s = tips['size'] * 10)
plt.show()

# %% [markdown]
# 4. markers = (표현하고자 하는 기호)
# 산점도 그래프의 점을 다른 기호로 표현하고 싶다면 markers 인자값에 표현하고자 하는 기호를 [리스트]에 담아 전달

# %%
#scatter = sns.lmplot(x='total_bill', y='tip', data=tips, fit_reg=False, hue='sex', 
#                     markers=['o','x'],scatter_kws={'s': tips['size']*10})

# 위의 예제는 오류가 떠서 다른 방식 사용
scatter = sns.relplot(x = 'total_bill', y = 'tip', data = tips, hue = 'sex', 
                     style = 'sex', s = tips['size'] * 10) 
plt.show()

# %% [markdown]
# 5. lmplot 메서드로 4개의 데이터 그룹에 대한 그래프 한 번에 그리기

# %%
#fit_reg 인자는 회귀선의 유무를 지정하는 값
anscombe_plot = sns.lmplot(x='x', y='y', data=anscombe, fit_reg=False)

# %% [markdown]
# 6. 그룹별로 그래프 나누어 그리기
# - lmplot 메서드에 추가로 col, col_warp 인자 설정
# col_warp = (그래프를 그릴열의 최댓값), col = (데이터 그룹을 구분할 열(dataset)) 지정

# %%
#col_wrap이 값을 1,2,3,4 중 하나의 값으로 조정
anscombe_plot = sns.lmplot(x='x', y='y', data=anscombe, fit_reg=False, col='dataset', col_wrap=2)

# %% [markdown]
# \* FacetGrid 클래스로 그룹별 그래프 그리기(간편)
# 1. FacetGrid에 데이터프레임과 그룹을 구분할 열 이름 전달해 객체 생성
# facet.map(그래프의 종류(distplot), x축으로 지정할 열 이름) - 히스토그램, 밀집도, 양탄자 그래프 그릴 수 있음.

# %%
facet = sns.FacetGrid(tips, col='time') 
facet.map(sns.distplot, 'total_bill', rug=True)
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# /usr/local/lib/python3.9/dist-packages/seaborn/axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)

# %% [markdown]
# 2. 다변량 그래프 그리기
# tips 데이터 집합의 day 열로 그룹 구분

# %%
facet = sns.FacetGrid(tips, col='day', hue='sex') 
facet = facet.map(plt.scatter, 'total_bill', 'tip') 
facet = facet.add_legend( )

# %% [markdown]
# 3. 더 많은 변수 사용

# %%
facet = sns.FacetGrid(tips, col='time', row='smoker', hue='sex') 
facet.map(plt.scatter, 'total_bill', 'tip')

# %% [markdown]
# **04-4. 데이터프레임과 시리즈로 그래프 그리기**(간편)

# %% [markdown]
# 1. 히스토그램 그리기
# plot.hist()

# %%
ax = plt.subplots( )
ax = tips['total_bill'].plot.hist( )

# %% [markdown]
# 2. 투명도 조절
# hist(alpha, bins, ax 인자 사용)
# alpha: 투명도, bins: x축의 간격

# %%
fig, ax = plt.subplots() 
ax = tips[['total_bill', 'tip']].plot.hist(alpha=0.5, bins=20, ax=ax)

# %% [markdown]
# 3. kde: 밀집도, scatter: 산점도 그래프, hexbin: 육각 그래프

# %%
ax = plt.subplots()
ax = tips['tip'].plot.kde( )

# %%
fig, ax= plt.subplots()
ax=tips.plot.scatter(x='total_bill', y='tip', ax=ax)
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
fig, ax = plt.subplots( )
ax = tips.plot.hexbin(x='total_bill', y='tip', ax=ax)

# %% [markdown]
# 4. gridsize: 육각 그래프의 육각형 크기 변경

# %%
fig, ax = plt.subplots( )
ax = tips.plot.hexbin(x='total_bill', y='tip', gridsize=10, ax=ax)

# %% [markdown]
# 5. box 메서드를 사용하여 그린 박스 그래프

# %%
fig, ax = plt.subplots( ) 
ax = tips.plot.box(ax=ax)

# %% [markdown]
# **04-5. seaborn 라이브러리로 그래프 스타일 설정하기**
# - set_style 메서드 사용
# 스타일을 적용할 부분에서 한 번만 실행하면 이후의 그래프 모두 지정한 스타일로 바뀜.
# seaborn 라이브러리 스타일(5종류): darkgrid, whitegrid, dark, white, ticks

# %% [markdown]
# 그래프에 스타일 지정하기

# %%
fig, ax = plt.subplots( )
ax = sns.violinplot(x='time', y='total_bill', hue='sex', data=tips, split=True)

# %% [markdown]
# whitegrid- 그래프 배경에 가로 줄이 생긴다

# %%
sns.set_style('whitegrid') 
fig, ax = plt.subplots( )
ax = sns.violinplot(x='time', y='total_bill', hue='sex', data=tips, split=True)

# %% [markdown]
# for문 이용해 모든 스타일 하나씩 적용해보기

# %%
fig = plt.figure( )
seaborn_styles = ['darkgrid', 'whitegrid', 'dark', 'white', 'ticks']
for idx, style in enumerate(seaborn_styles):
  plot_position = idx + 1
  with sns.axes_style(style):
    ax = fig.add_subplot(2, 3, plot_position)
    violin = sns.violinplot(x='time' ,y='total_bill', data=tips,ax=ax)
    violin.set_title(style)
fig.tight_layout()

# %% [markdown]
# **마무리**
# 다양한 그래프를 그리는 방법에 대해 알아보았다. 데이터 시각화는 데이터를 분석하기 위해 반드시 알아야 하는 중요한 요소이다.
# (더 많은 정보를 알고 싶다면 구글에 seaborn documentation이나 matplotlib documentation을 검색하여 나오는 공식 문서를 참고.)
